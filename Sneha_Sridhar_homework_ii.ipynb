# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-S2003/bootcamp_spr25/blob/main/Sneha_Sridhar_homework_ii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Homework 2: Introduction to `pandas`

# %% [markdown]
# ##### Problem 1: Import the libraries
#
# Below, import `pandas` using standard alias's as we used in class.

# %%
import pandas as pd
df = pd.DataFrame()

# %% [markdown]
# ##### Problem 2: Make a `DataFrame` from `dict`
#
# Use the dictionary `ex_2_data` to build a pandas DataFrame named `dog_df` below.

# %%
ex_2_data = {'name': ['Lenny', 'Hardy', 'Oden', 'Hennessy', 'Cliff'],
             'breed': ['wildman', 'lab', 'lab', 'pitbull', 'boxer'],
             'weight': [40, 70, 65, 73, 46],
             'age': [3, 5, 13, 15, 4]}

# %%
dog_df = pd.DataFrame(ex_2_data)
dog_df
# Out:
#        name    breed  weight  age
# 0     Lenny  wildman      40    3
# 1     Hardy      lab      70    5
# 2      Oden      lab      65   13
# 3  Hennessy  pitbull      73   15
# 4     Cliff    boxer      46    4

# %% [markdown]
# ##### Problem 3: Columns of a DataFrame
#
# Below, extract the columns from the DataFrame `dog_df`.

# %%
dog_df.columns
# Out:
# Index(['name', 'breed', 'weight', 'age'], dtype='object')

# %% [markdown]
# ##### Problem 4: Basic Information
#
# Use the `.info()` method to display basic information about `dog_df`.

# %%
dog_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   breed   5 non-null      object
#  2   weight  5 non-null      int64
#  3   age     5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# #### A Second Dataset
#
# Below, we load a built in dataset from the `seaborn` library.  We will use this library later in the course for data visualization, but for now just note that the object `titanic_df` is a DataFrame and we can just use the `.load_dataset` function to access it.

# %%
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')

# %% [markdown]
# ##### Problem 5: Numerical Summaries
#
# Use the `.describe` method to display numerical summaries for the columns in `titanic_df`.

# %%
titanic_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ##### Problem 6: Categorical Summaries
#
# Use the `.describe()` method to display summaries of *only the categorical columns*.  (**Hint**: what does the `include` argument do?)

# %%
include = ['object']
titanic_df.describe(include = include)
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# ##### Problem 7: Shape of the data
#
# How many rows and columns are in the DataFrame `titanic_df`?

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df.shape
# Out:
# (891, 15)

# %% [markdown]
# ##### Problem 8: Summaries
#
# What is the mean and standard deviation of the `age` column?

# %%
titanic_df.agg({'age': ['mean', 'std']})
# Out:
#             age
# mean  29.699118
# std   14.526497

# %% [markdown]
# ##### Problem 9: Summaries by sex
#
# Now, determine the mean and standard deviation for the male passengers `age`.

# %%
titanic_df[titanic_df['sex'] == 'male']['age'].agg(['mean', 'std'])
# Out:
# mean    30.726645
# std     14.678201
# Name: age, dtype: float64

# %% [markdown]
# ##### Problem 10: Young people in first class
#
# Subset the data to passengers under the age of 18.  How many of these passengers traveled first class?

# %%
titanic_df.groupby(titanic['age'] < 18)['first class'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-fd3ca8b804c4> in <cell line: 0>()
# ----> 1 titanic_df.groupby(titanic['age'] < 18)['first class'].mean()
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# ##### Problem 11: Older people embarked
#
# Subset the data `titanic_df` to people over the age of 70.  What was the most common point of departure for them (`embark_town`)?

# %% [markdown]
# ##### Problem 12: Survival Rate
#
# Use the `survived` column to compute the survival rate for all passengers.

# %% [markdown]
# ##### Problem 13: Renaming Columns
#
# Rename the column `sibsp` to `num_siblings`.

# %% [markdown]
# ##### Problem 14: Dropping Columns
#
# Drop the column `adult_male` from `titanic_df`.

# %% [markdown]
# #### Reading
#
# Read through the chapter *Pandas Basics* in [Python for Data Analysis](https://wesmckinney.com/book/pandas-basics).  Identify three methods or techniques for working with a `DataFrame` that are new to you and demonstrate their use with the data loaded below.  One way to think about it is to frame a clear question you have about the data and use the pandas library to answer that question.  These should be *descriptive* questions that summarize the dataset rather than *predictive* questions that seek to predict one value using others.

# %%
from sklearn.datasets import fetch_openml

# %%
wages = fetch_openml(data_id = 534).frame

# %%
wages.head()
# Out:
#    EDUCATION SOUTH     SEX  EXPERIENCE  ...      RACE  OCCUPATION         SECTOR       MARR
# 0          8    no  female          21  ...  Hispanic       Other  Manufacturing    Married
# 1          9    no  female          42  ...     White       Other  Manufacturing    Married
# 2         12    no    male           1  ...     White       Other  Manufacturing  Unmarried
# 3         12    no    male           4  ...     White       Other          Other  Unmarried
# 4         12    no    male          17  ...     White       Other          Other    Married
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Data in the News
#
# Last week there was quite a stir about the Deepseek model released from workers in China.  A consistent voice in AI is Meta's head of AI and NYU Professor Yann LeCun.  Read through the Business Insider article [here](https://www.businessinsider.com/meta-yann-lecun-ai-scientist-deepseek-markets-reaction-inference-2025-1) and give your perspective on what LeCun believes to be a misunderstanding surrounding Deepseek and general development of Artificial Intelligence models.  Write your response in complete sentences using a markdown cell below.
